# %%
import pandas as pd
import numpy as np

# %%
assembly_data = pd.read_csv('transposed_report.tsv', sep='\t')

# %%
assembly_data['k'] = assembly_data['Assembly'].apply(lambda x: x.split('_')[0][1:])

# %%
assembly_data['coverage'] = assembly_data['Assembly'].apply(lambda x: x.split('_')[2][:len(x.split('_')[2])-1])

# %%
assembly_data['fragment_length'] = assembly_data['Assembly'].apply(lambda x: 600 if '600m' in x else 200)

# %%
reads = assembly_data['Assembly'].apply(lambda x: x.strip('-contigs'))

# %%
assembly_data.index = pd.DataFrame(index=reads).index

# %%
assembly_data
# Out:
#                                           Assembly  # contigs (>= 0 bp)  \
# Assembly
# k30_ecoli_100X_1          k30_ecoli_100X_1-contigs                  574
# k36_ecoli_100X_1          k36_ecoli_100X_1-contigs                  435
# k42_ecoli_100X_1          k42_ecoli_100X_1-contigs                  376
# k48_ecoli_100X_1          k48_ecoli_100X_1-contigs                  339
# k54_ecoli_100X_1          k54_ecoli_100X_1-contigs                  295
# k60_ecoli_100X_1          k60_ecoli_100X_1-contigs                  284
# k66_ecoli_100X_1          k66_ecoli_100X_1-contigs                  264
# k72_ecoli_100X_1          k72_ecoli_100X_1-contigs                  257
# k78_ecoli_100X_1          k78_ecoli_100X_1-contigs                  242
# k84_ecoli_100X_1          k84_ecoli_100X_1-contigs                  225
# k90_ecoli_100X_1          k90_ecoli_100X_1-contigs                  208
# k96_ecoli_100X_1          k96_ecoli_100X_1-contigs                  191
# k30_ecoli_100X_10        k30_ecoli_100X_10-contigs                  574
# k36_ecoli_100X_10        k36_ecoli_100X_10-contigs                  446
# k42_ecoli_100X_10        k42_ecoli_100X_10-contigs                  364
# k48_ecoli_100X_10        k48_ecoli_100X_10-contigs                  335
# k54_ecoli_100X_10        k54_ecoli_100X_10-contigs                  291
# k60_ecoli_100X_10        k60_ecoli_100X_10-contigs                  277
# k66_ecoli_100X_10        k66_ecoli_100X_10-contigs                  261
# k72_ecoli_100X_10        k72_ecoli_100X_10-contigs                  253
# k78_ecoli_100X_10        k78_ecoli_100X_10-contigs                  243
# k84_ecoli_100X_10        k84_ecoli_100X_10-contigs                  223
# k90_ecoli_100X_10        k90_ecoli_100X_10-contigs                  207
# k96_ecoli_100X_10        k96_ecoli_100X_10-contigs                  195
# k30_ecoli_100X_11        k30_ecoli_100X_11-contigs                  563
# k36_ecoli_100X_11        k36_ecoli_100X_11-contigs                  441
# k42_ecoli_100X_11        k42_ecoli_100X_11-contigs                  363
# k48_ecoli_100X_11        k48_ecoli_100X_11-contigs                  334
# k54_ecoli_100X_11        k54_ecoli_100X_11-contigs                  294
# k60_ecoli_100X_11        k60_ecoli_100X_11-contigs                  279
# ...                                            ...                  ...
# k66_ecoli_50X_600m_7  k66_ecoli_50X_600m_7-contigs                  135
# k72_ecoli_50X_600m_7  k72_ecoli_50X_600m_7-contigs                  134
# k78_ecoli_50X_600m_7  k78_ecoli_50X_600m_7-contigs                  133
# k84_ecoli_50X_600m_7  k84_ecoli_50X_600m_7-contigs                  123
# k90_ecoli_50X_600m_7  k90_ecoli_50X_600m_7-contigs                  117
# k96_ecoli_50X_600m_7  k96_ecoli_50X_600m_7-contigs                  106
# k30_ecoli_50X_600m_8  k30_ecoli_50X_600m_8-contigs                  407
# k36_ecoli_50X_600m_8  k36_ecoli_50X_600m_8-contigs                  266
# k42_ecoli_50X_600m_8  k42_ecoli_50X_600m_8-contigs                  210
# k48_ecoli_50X_600m_8  k48_ecoli_50X_600m_8-contigs                  185
# k54_ecoli_50X_600m_8  k54_ecoli_50X_600m_8-contigs                  154
# k60_ecoli_50X_600m_8  k60_ecoli_50X_600m_8-contigs                  144
# k66_ecoli_50X_600m_8  k66_ecoli_50X_600m_8-contigs                  139
# k72_ecoli_50X_600m_8  k72_ecoli_50X_600m_8-contigs                  135
# k78_ecoli_50X_600m_8  k78_ecoli_50X_600m_8-contigs                  135
# k84_ecoli_50X_600m_8  k84_ecoli_50X_600m_8-contigs                  124
# k90_ecoli_50X_600m_8  k90_ecoli_50X_600m_8-contigs                  118
# k96_ecoli_50X_600m_8  k96_ecoli_50X_600m_8-contigs                  107
# k30_ecoli_50X_600m_9  k30_ecoli_50X_600m_9-contigs                  393
# k36_ecoli_50X_600m_9  k36_ecoli_50X_600m_9-contigs                  295
# k42_ecoli_50X_600m_9  k42_ecoli_50X_600m_9-contigs                  216
# k48_ecoli_50X_600m_9  k48_ecoli_50X_600m_9-contigs                  188
# k54_ecoli_50X_600m_9  k54_ecoli_50X_600m_9-contigs                  149
# k60_ecoli_50X_600m_9  k60_ecoli_50X_600m_9-contigs                  146
# k66_ecoli_50X_600m_9  k66_ecoli_50X_600m_9-contigs                  134
# k72_ecoli_50X_600m_9  k72_ecoli_50X_600m_9-contigs                  133
# k78_ecoli_50X_600m_9  k78_ecoli_50X_600m_9-contigs                  132
# k84_ecoli_50X_600m_9  k84_ecoli_50X_600m_9-contigs                  126
# k90_ecoli_50X_600m_9  k90_ecoli_50X_600m_9-contigs                  119
# k96_ecoli_50X_600m_9  k96_ecoli_50X_600m_9-contigs                  108
#
#                       # contigs (>= 1000 bp)  # contigs (>= 5000 bp)  \
# Assembly
# k30_ecoli_100X_1                         149                     111
# k36_ecoli_100X_1                         129                     101
# k42_ecoli_100X_1                         119                      91
# k48_ecoli_100X_1                         109                      88
# k54_ecoli_100X_1                         103                      85
# k60_ecoli_100X_1                          98                      80
# k66_ecoli_100X_1                          97                      78
# k72_ecoli_100X_1                          92                      74
# k78_ecoli_100X_1                          90                      74
# k84_ecoli_100X_1                          89                      72
# k90_ecoli_100X_1                          86                      70
# k96_ecoli_100X_1                          86                      69
# k30_ecoli_100X_10                        149                     115
# k36_ecoli_100X_10                        134                     102
# k42_ecoli_100X_10                        118                      92
# k48_ecoli_100X_10                        109                      88
# k54_ecoli_100X_10                        100                      81
# k60_ecoli_100X_10                         96                      79
# k66_ecoli_100X_10                         94                      76
# k72_ecoli_100X_10                         91                      74
# k78_ecoli_100X_10                         91                      75
# k84_ecoli_100X_10                         88                      71
# k90_ecoli_100X_10                         85                      69
# k96_ecoli_100X_10                         84                      67
# k30_ecoli_100X_11                        146                     112
# k36_ecoli_100X_11                        133                     102
# k42_ecoli_100X_11                        116                      89
# k48_ecoli_100X_11                        106                      86
# k54_ecoli_100X_11                        102                      85
# k60_ecoli_100X_11                         98                      81
# ...                                      ...                     ...
# k66_ecoli_50X_600m_7                      66                      57
# k72_ecoli_50X_600m_7                      65                      57
# k78_ecoli_50X_600m_7                      64                      56
# k84_ecoli_50X_600m_7                      62                      55
# k90_ecoli_50X_600m_7                      60                      53
# k96_ecoli_50X_600m_7                      61                      53
# k30_ecoli_50X_600m_8                      86                      71
# k36_ecoli_50X_600m_8                      74                      60
# k42_ecoli_50X_600m_8                      66                      56
# k48_ecoli_50X_600m_8                      65                      54
# k54_ecoli_50X_600m_8                      64                      56
# k60_ecoli_50X_600m_8                      64                      56
# k66_ecoli_50X_600m_8                      64                      56
# k72_ecoli_50X_600m_8                      63                      56
# k78_ecoli_50X_600m_8                      63                      56
# k84_ecoli_50X_600m_8                      62                      55
# k90_ecoli_50X_600m_8                      61                      54
# k96_ecoli_50X_600m_8                      62                      54
# k30_ecoli_50X_600m_9                      85                      71
# k36_ecoli_50X_600m_9                      75                      61
# k42_ecoli_50X_600m_9                      66                      55
# k48_ecoli_50X_600m_9                      69                      56
# k54_ecoli_50X_600m_9                      66                      56
# k60_ecoli_50X_600m_9                      65                      57
# k66_ecoli_50X_600m_9                      63                      56
# k72_ecoli_50X_600m_9                      62                      56
# k78_ecoli_50X_600m_9                      64                      57
# k84_ecoli_50X_600m_9                      64                      57
# k90_ecoli_50X_600m_9                      61                      54
# k96_ecoli_50X_600m_9                      62                      54
#
#                       # contigs (>= 10000 bp)  # contigs (>= 25000 bp)  \
# Assembly
# k30_ecoli_100X_1                           96                       57
# k36_ecoli_100X_1                           83                       54
# k42_ecoli_100X_1                           81                       57
# k48_ecoli_100X_1                           77                       54
# k54_ecoli_100X_1                           74                       53
# k60_ecoli_100X_1                           69                       51
# k66_ecoli_100X_1                           68                       51
# k72_ecoli_100X_1                           64                       50
# k78_ecoli_100X_1                           65                       51
# k84_ecoli_100X_1                           65                       51
# k90_ecoli_100X_1                           63                       49
# k96_ecoli_100X_1                           62                       49
# k30_ecoli_100X_10                          98                       60
# k36_ecoli_100X_10                          84                       58
# k42_ecoli_100X_10                          79                       58
# k48_ecoli_100X_10                          77                       54
# k54_ecoli_100X_10                          70                       52
# k60_ecoli_100X_10                          68                       51
# k66_ecoli_100X_10                          66                       51
# k72_ecoli_100X_10                          65                       51
# k78_ecoli_100X_10                          66                       52
# k84_ecoli_100X_10                          65                       52
# k90_ecoli_100X_10                          63                       50
# k96_ecoli_100X_10                          61                       51
# k30_ecoli_100X_11                          95                       63
# k36_ecoli_100X_11                          86                       60
# k42_ecoli_100X_11                          79                       58
# k48_ecoli_100X_11                          76                       54
# k54_ecoli_100X_11                          75                       54
# k60_ecoli_100X_11                          71                       52
# ...                                       ...                      ...
# k66_ecoli_50X_600m_7                       51                       44
# k72_ecoli_50X_600m_7                       51                       44
# k78_ecoli_50X_600m_7                       50                       44
# k84_ecoli_50X_600m_7                       49                       43
# k90_ecoli_50X_600m_7                       48                       42
# k96_ecoli_50X_600m_7                       48                       42
# k30_ecoli_50X_600m_8                       62                       51
# k36_ecoli_50X_600m_8                       53                       46
# k42_ecoli_50X_600m_8                       51                       45
# k48_ecoli_50X_600m_8                       50                       44
# k54_ecoli_50X_600m_8                       50                       44
# k60_ecoli_50X_600m_8                       50                       44
# k66_ecoli_50X_600m_8                       50                       44
# k72_ecoli_50X_600m_8                       50                       44
# k78_ecoli_50X_600m_8                       50                       44
# k84_ecoli_50X_600m_8                       49                       43
# k90_ecoli_50X_600m_8                       49                       43
# k96_ecoli_50X_600m_8                       49                       43
# k30_ecoli_50X_600m_9                       62                       51
# k36_ecoli_50X_600m_9                       54                       46
# k42_ecoli_50X_600m_9                       51                       44
# k48_ecoli_50X_600m_9                       52                       45
# k54_ecoli_50X_600m_9                       50                       43
# k60_ecoli_50X_600m_9                       51                       44
# k66_ecoli_50X_600m_9                       50                       44
# k72_ecoli_50X_600m_9                       50                       44
# k78_ecoli_50X_600m_9                       51                       44
# k84_ecoli_50X_600m_9                       50                       43
# k90_ecoli_50X_600m_9                       49                       42
# k96_ecoli_50X_600m_9                       49                       42
#
#                       # contigs (>= 50000 bp)  Total length (>= 0 bp)  \
# Assembly
# k30_ecoli_100X_1                           27                 4600795
# k36_ecoli_100X_1                           32                 4607285
# k42_ecoli_100X_1                           31                 4617624
# k48_ecoli_100X_1                           30                 4621162
# k54_ecoli_100X_1                           32                 4623081
# k60_ecoli_100X_1                           32                 4628369
# k66_ecoli_100X_1                           32                 4628447
# k72_ecoli_100X_1                           31                 4634937
# k78_ecoli_100X_1                           32                 4634528
# k84_ecoli_100X_1                           32                 4632976
# k90_ecoli_100X_1                           29                 4637918
# k96_ecoli_100X_1                           30                 4638799
# k30_ecoli_100X_10                          28                 4599863
# k36_ecoli_100X_10                          32                 4605880
# k42_ecoli_100X_10                          30                 4614012
# k48_ecoli_100X_10                          31                 4622117
# k54_ecoli_100X_10                          34                 4623537
# k60_ecoli_100X_10                          33                 4627413
# k66_ecoli_100X_10                          33                 4627832
# k72_ecoli_100X_10                          32                 4636068
# k78_ecoli_100X_10                          32                 4634269
# k84_ecoli_100X_10                          32                 4632886
# k90_ecoli_100X_10                          29                 4637401
# k96_ecoli_100X_10                          30                 4639671
# k30_ecoli_100X_11                          29                 4601547
# k36_ecoli_100X_11                          31                 4608721
# k42_ecoli_100X_11                          31                 4617935
# k48_ecoli_100X_11                          31                 4621182
# k54_ecoli_100X_11                          32                 4623856
# k60_ecoli_100X_11                          32                 4628717
# ...                                       ...                     ...
# k66_ecoli_50X_600m_7                       28                 4644990
# k72_ecoli_50X_600m_7                       28                 4645094
# k78_ecoli_50X_600m_7                       28                 4644606
# k84_ecoli_100X_10       ...     113390  106418  58239  58239    14     15
# k90_ecoli_100X_10       ...     124104  124104  59186  59186    13     13
# k96_ecoli_100X_10       ...     125806  125806  59186  59186    14     14
# k30_ecoli_100X_11       ...      56323   55588  33558  32001    23     24
# k36_ecoli_100X_11       ...      65898   65484  41983  38827    21     22
# k42_ecoli_100X_11       ...      83202   78919  42502  42318    18     19
# k48_ecoli_100X_11       ...      96181   95861  45278  42324    16     17
# k54_ecoli_100X_11       ...      95957   95957  49432  45672    16     16
# k60_ecoli_100X_11       ...     106366   96062  53764  53764    15     16
# ...                     ...        ...     ...    ...    ...   ...    ...
# k66_ecoli_50X_600m_7    ...     135012  135012  80392  80392    11     11
# k72_ecoli_50X_600m_7    ...     135012  135012  80392  80392    11     11
# k78_ecoli_50X_600m_7    ...     135012  135012  80392  80392    11     11
# k84_ecoli_50X_600m_7    ...     175451  175451  80392  80392    10     10
# k90_ecoli_50X_600m_7    ...     175457  175457  87969  87969    10     10
# k96_ecoli_50X_600m_7    ...     175463  175463  87975  87975    10     10
# k30_ecoli_50X_600m_8    ...     110256  110256  57326  56080    14     14
# k36_ecoli_50X_600m_8    ...     132346  132346  68945  68945    12     12
# k42_ecoli_50X_600m_8    ...     132439  132439  79310  79310    12     12
# k48_ecoli_50X_600m_8    ...     135012  135012  79316  79316    11     11
# k54_ecoli_50X_600m_8    ...     135012  135012  79001  79001    11     11
# k60_ecoli_50X_600m_8    ...     135012  135012  80392  80392    11     11
# k66_ecoli_50X_600m_8    ...     135012  135012  80392  80392    11     11
# k72_ecoli_50X_600m_8    ...     135012  135012  80392  80392    11     11
# k78_ecoli_50X_600m_8    ...     135012  135012  80392  80392    11     11
# k84_ecoli_50X_600m_8    ...     135012  135012  84003  84003    11     11
# k90_ecoli_50X_600m_8    ...     135012  135012  84009  84009    11     11
# k96_ecoli_50X_600m_8    ...     135012  135012  84015  84015    11     11
# k30_ecoli_50X_600m_9    ...     111088  111088  56880  56080    14     14
# k36_ecoli_50X_600m_9    ...     132352  127222  68945  66202    12     13
# k42_ecoli_50X_600m_9    ...     133586  133586  79310  79310    11     11
# k48_ecoli_50X_600m_9    ...     135012  135012  79316  79316    11     11
# k54_ecoli_50X_600m_9    ...     135012  135012  79100  79100    11     11
# k60_ecoli_50X_600m_9    ...     135012  135012  80392  80392    11     11
# k66_ecoli_50X_600m_9    ...     135012  135012  80392  80392    11     11
# k72_ecoli_50X_600m_9    ...     135012  135012  80392  80392    11     11
# k78_ecoli_50X_600m_9    ...     135012  135012  80392  80392    11     11
# k84_ecoli_50X_600m_9    ...     135012  135012  84229  84229    11     11
# k90_ecoli_50X_600m_9    ...     175276  175276  87969  87969    10     10
# k96_ecoli_50X_600m_9    ...     175282  175282  87975  87975    10     10
#
#                       LA75  LGA75   k  coverage
# Assembly
# k30_ecoli_100X_1        47     49  30       100
# k36_ecoli_100X_1        40     41  36       100
# k42_ecoli_100X_1        38     39  42       100
# k48_ecoli_100X_1        35     36  48       100
# k54_ecoli_100X_1        33     34  54       100
# k60_ecoli_100X_1        31     32  60       100
# k66_ecoli_100X_1        31     31  66       100
# k72_ecoli_100X_1        29     29  72       100
# k78_ecoli_100X_1        29     30  78       100
# k84_ecoli_100X_1        30     30  84       100
# k90_ecoli_100X_1        27     27  90       100
# k96_ecoli_100X_1        27     27  96       100
# k30_ecoli_100X_10       50     52  30       100
# k36_ecoli_100X_10       42     44  36       100
# k42_ecoli_100X_10       40     41  42       100
# k48_ecoli_100X_10       36     37  48       100
# k54_ecoli_100X_10       33     33  54       100
# k60_ecoli_100X_10       31     32  60       100
# k66_ecoli_100X_10       31     31  66       100
# k72_ecoli_100X_10       30     30  72       100
# k78_ecoli_100X_10       30     31  78       100
# k84_ecoli_100X_10       30     30  84       100
# k90_ecoli_100X_10       27     27  90       100
# k96_ecoli_100X_10       27     27  96       100
# k30_ecoli_100X_11       49     51  30       100
# k36_ecoli_100X_11       44     45  36       100
# k42_ecoli_100X_11       38     39  42       100
# k48_ecoli_100X_11       34     35  48       100
# k54_ecoli_100X_11       33     34  54       100
# k60_ecoli_100X_11       32     32  60       100
# ...                    ...    ...  ..       ...
# k66_ecoli_50X_600m_7    22     22  66        50
# k72_ecoli_50X_600m_7    22     22  72        50
# k78_ecoli_50X_600m_7    22     22  78        50
# k84_ecoli_50X_600m_7    21     21  84        50
# k90_ecoli_50X_600m_7    20     20  90        50
# k96_ecoli_50X_600m_7    20     20  96        50
# k30_ecoli_50X_600m_8    28     29  30        50
# k36_ecoli_50X_600m_8    24     24  36        50
# k42_ecoli_50X_600m_8    23     23  42        50
# k48_ecoli_50X_600m_8    22     22  48        50
# k54_ecoli_50X_600m_8    22     22  54        50
# k60_ecoli_50X_600m_8    22     22  60        50
# k66_ecoli_50X_600m_8    22     22  66        50
# k72_ecoli_50X_600m_8    22     22  72        50
# k78_ecoli_50X_600m_8    22     22  78        50
# k84_ecoli_50X_600m_8    21     21  84        50
# k90_ecoli_50X_600m_8    21     21  90        50
# k96_ecoli_50X_600m_8    21     21  96        50
# k30_ecoli_50X_600m_9    28     29  30        50
# k36_ecoli_50X_600m_9    24     25  36        50
# k42_ecoli_50X_600m_9    22     22  42        50
# k48_ecoli_50X_600m_9    22     22  48        50
# k54_ecoli_50X_600m_9    21     21  54        50
# k60_ecoli_50X_600m_9    22     22  60        50
# k66_ecoli_50X_600m_9    22     22  66        50
# k72_ecoli_50X_600m_9    22     22  72        50
# k78_ecoli_50X_600m_9    22     22  78        50
# k84_ecoli_50X_600m_9    21     21  84        50
# k90_ecoli_50X_600m_9    20     20  90        50
# k96_ecoli_50X_600m_9    20     20  96        50
#
# [1260 rows x 51 columns]

# %% [markdown]
# # gather all ntcard data

# %%
root = '/projects/btl/eerhan/simulated_data/ecoli'
#files = ['freq_k128.hist', 'freq_k32.hist', 'freq_k42.hist', 'freq_k54.hist', 'freq_k64.hist', 'freq_k72.hist', 'freq_k84.hist', 'freq_k96.hist',
#'freq_k30.hist', 'freq_k36.hist', 'freq_k48.hist', 'freq_k60.hist', 'freq_k66.hist', 'freq_k78.hist', 'freq_k90.hist']
ntcard_data = pd.DataFrame(dtype=np.float64)
for read in reads:
    read_dir = read[4:]
    k = read[:3]
    ntcard_path = "{}/{}/ntcard/freq_{}.hist".format(root, read_dir, k)
    temp = pd.read_csv(ntcard_path, sep='\t', index_col=0, header=None, names=["{}_{}".format(k, read_dir)])
    ntcard_data["{}_{}".format(k, read_dir)] = temp["{}_{}".format(k, read_dir)]

# %%
ntcard_data = ntcard_data.T

# %%
ntcard_data.index
# Out:
# Index([u'k30_ecoli_100X_1', u'k36_ecoli_100X_1', u'k42_ecoli_100X_1',
#        u'k48_ecoli_100X_1', u'k54_ecoli_100X_1', u'k60_ecoli_100X_1',
#        u'k66_ecoli_100X_1', u'k72_ecoli_100X_1', u'k78_ecoli_100X_1',
#        u'k84_ecoli_100X_1',
#        ...
#        u'k42_ecoli_50X_600m_9', u'k48_ecoli_50X_600m_9',
#        u'k54_ecoli_50X_600m_9', u'k60_ecoli_50X_600m_9',
#        u'k66_ecoli_50X_600m_9', u'k72_ecoli_50X_600m_9',
#        u'k78_ecoli_50X_600m_9', u'k84_ecoli_50X_600m_9',
#        u'k90_ecoli_50X_600m_9', u'k96_ecoli_50X_600m_9'],
#       dtype='object', length=1260)

# %%
all_data = pd.concat([assembly_data, ntcard_data], axis=1)

# %%
# Define best assembly
threshold = np.percentile(all_data['NGA50'], 90)
all_data['good_quality'] = all_data['NGA50'].apply(lambda x: True if x > threshold else False)

# %% [markdown]
# # Machine learning

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression, ElasticNet, Lasso, Ridge
from sklearn.svm import SVR

# %%
X = pd.concat([all_data.loc[:, 'F1':'f300'], all_data[['k', 'coverage', 'fragment_length']]], axis=1)
y = all_data['good_quality']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %% [markdown]
# Logistic regression

# %%
l_reg = LogisticRegression()

# %%
l_reg.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
l_reg.score(X_test, y_test)
# Out:
# 0.91428571428571426

# %%
len(y[y])
# Out:
# 102

# %%
len(y)
# Out:
# 1260

# %%
y_test[l_reg.predict(X_test)]
# Out:
# k42_ecoli_200X_600m_15    True
# k42_ecoli_200X_600m_5     True
# k42_ecoli_200X_600m_7     True
# Name: good_quality, dtype: bool

# %% [markdown]
# Lasso and ElasticNet regression

# %%
X = pd.concat([all_data.loc[:, 'F1':'f300'], all_data[['k', 'coverage', 'fragment_length']]], axis=1)
y = all_data['NGA50']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
lasso_model = Lasso(alpha=0.01)

# %%
lasso_model.fit(X_train, y_train)
# Out:
# Lasso(alpha=0.01, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=None,
#    selection='cyclic', tol=0.0001, warm_start=False)

# %%
lasso_model.score(X_test, y_test)
# Out:
# 0.80689056414125959

# %%
elastic_model = ElasticNet(alpha=0.01)

# %%
elastic_model.fit(X_train, y_train)
# Out:
# ElasticNet(alpha=0.01, copy_X=True, fit_intercept=True, l1_ratio=0.5,
#       max_iter=1000, normalize=False, positive=False, precompute=False,
#       random_state=None, selection='cyclic', tol=0.0001, warm_start=False)

# %%
elastic_model.score(X_test, y_test)
# Out:
# 0.80688709966439742

# %% [markdown]
# Support Vector Regression and Ridge Regression

# %%
svr_model = SVR(C=1.0, kernel='linear')

# %%
svr_model.fit(X_train, y_train)

# %%
svr_model.score(X_test, y_test)

# %%
ridge_model = Ridge(alpha=0.1)

# %%
ridge_model.fit(X_train, y_train)

# %%
ridge_model.score(X_test, y_test)
